# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys;sys.path.extend(['/opt/conda/lib/python3.11/site-packages', '/home/ovewh/Climaso/workflow/rules', '/home/ovewh/Climaso/workflow', '/opt/conda/bin', '/opt/conda/lib/python3.11', '/opt/conda/lib/python3.11/lib-dynload', '/opt/conda/lib/python3.11/site-packages', '/home/ovewh/Climaso/workflow/notebooks/dust_analysis']);import pickle;from snakemake import script;script.snakemake = pickle.loads(b'\x80\x04\x95\x18\x1e\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c@results/piClim-2xdust/so2/so2_piClim-2xdust_UKESM1-0-LL_Ayear.nc\x94\x8cDresults/piClim-2xdust/so2/so2_piClim-2xdust_MPI-ESM-1-2-HAM_Ayear.nc\x94\x8cFresults/piClim-2xdust/so2/so2_piClim-2xdust_EC-Earth3-AerChem_Ayear.nc\x94\x8c@results/piClim-2xdust/so2/so2_piClim-2xdust_UKESM1-0-LL_Ayear.nc\x94\x8cDresults/piClim-2xdust/so2/so2_piClim-2xdust_MPI-ESM-1-2-HAM_Ayear.nc\x94\x8cFresults/piClim-2xdust/so2/so2_piClim-2xdust_EC-Earth3-AerChem_Ayear.nc\x94\x8cZresults/piClim-2xdust/derived_variables/concso4/concso4_UKESM1-0-LL_piClim-2xdust_Ayear.nc\x94\x8cXresults/piClim-2xdust/derived_variables/cdncvi/cdncvi_UKESM1-0-LL_piClim-2xdust_Ayear.nc\x94\x8c^results/piClim-2xdust/derived_variables/concso4/concso4_MPI-ESM-1-2-HAM_piClim-2xdust_Ayear.nc\x94\x8c\\results/piClim-2xdust/derived_variables/cdncvi/cdncvi_MPI-ESM-1-2-HAM_piClim-2xdust_Ayear.nc\x94\x8c`results/piClim-2xdust/derived_variables/concso4/concso4_EC-Earth3-AerChem_piClim-2xdust_Ayear.nc\x94\x8c^results/piClim-2xdust/derived_variables/cdncvi/cdncvi_EC-Earth3-AerChem_piClim-2xdust_Ayear.nc\x94\x8c\\results/piClim-control/derived_variables/concso4/concso4_UKESM1-0-LL_piClim-control_Ayear.nc\x94\x8cZresults/piClim-control/derived_variables/cdncvi/cdncvi_UKESM1-0-LL_piClim-control_Ayear.nc\x94\x8c`results/piClim-control/derived_variables/concso4/concso4_MPI-ESM-1-2-HAM_piClim-control_Ayear.nc\x94\x8c^results/piClim-control/derived_variables/cdncvi/cdncvi_MPI-ESM-1-2-HAM_piClim-control_Ayear.nc\x94\x8cbresults/piClim-control/derived_variables/concso4/concso4_EC-Earth3-AerChem_piClim-control_Ayear.nc\x94\x8c`results/piClim-control/derived_variables/cdncvi/cdncvi_EC-Earth3-AerChem_piClim-control_Ayear.nc\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x08exp_vars\x94K\x00K\x03\x86\x94\x8c\tctrl_vars\x94K\x03K\x06\x86\x94\x8c\x10derived_exp_vars\x94K\x06K\x0c\x86\x94\x8c\x11derived_ctrl_vars\x94K\x0cK\x12\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh)h\x06\x8c\x0eAttributeGuard\x94\x93\x94)\x81\x94}\x94\x8c\x04name\x94h)sbh*h,)\x81\x94}\x94h/h*sbh\x1fh\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\nh\x0bh\x0ce}\x94(h\x1d}\x94h\']\x94(h)h*eh)h,)\x81\x94}\x94h/h)sbh*h,)\x81\x94}\x94h/h*sbubh!h3)\x81\x94(h\rh\x0eh\x0fe}\x94(h\x1d}\x94h\']\x94(h)h*eh)h,)\x81\x94}\x94h/h)sbh*h,)\x81\x94}\x94h/h*sbubh#h3)\x81\x94(h\x10h\x11h\x12h\x13h\x14h\x15e}\x94(h\x1d}\x94h\']\x94(h)h*eh)h,)\x81\x94}\x94h/h)sbh*h,)\x81\x94}\x94h/h*sbubh%h3)\x81\x94(h\x16h\x17h\x18h\x19h\x1ah\x1be}\x94(h\x1d}\x94h\']\x94(h)h*eh)h,)\x81\x94}\x94h/h)sbh*h,)\x81\x94}\x94h/h*sbubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c$results/figs/ACP_paper/figure_S9.png\x94a}\x94(h\x1d}\x94\x8c\x07outpath\x94K\x00N\x86\x94sh\']\x94(h)h*eh)h,)\x81\x94}\x94h/h)sbh*h,)\x81\x94}\x94h/h*sbh[hXub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x1d}\x94h\']\x94(h)h*eh)h,)\x81\x94}\x94h/h)sbh*h,)\x81\x94}\x94h/h*sbub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x1d}\x94h\']\x94(h)h*eh)h,)\x81\x94}\x94h/h)sbh*h,)\x81\x94}\x94h/h*sbub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x1d}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\']\x94(h)h*eh)h,)\x81\x94}\x94h/h)sbh*h,)\x81\x94}\x94h/h*sbh\x80K\x01h\x82K\x01h\x84h}ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x1d}\x94h\']\x94(h)h*eh)h,)\x81\x94}\x94h/h)sbh*h,)\x81\x94}\x94h/h*sbub\x8c\x06config\x94}\x94(\x8c\troot_nird\x94\x8c!/nird/datalake/NS9560K/ESGF/CMIP6\x94\x8c\x0broot_lustre\x94\x8c+/lustre/storeB/users/oveh/.synda/data/CMIP6\x94\x8c\x0broot_noresm\x94\x8c\x17/projects/NS9034K/CMIP6\x94\x8c\x0eroot_noresmdev\x94\x8c>/home/oveh/mnt/NIRD_data/NorESM2_AerChemMIP_rerun_bugfix/CMIP6\x94\x8c\x10root_nirdtoolkit\x94\x8c#/mnt/volume-for-ns9560k-esgf/CMIP6/\x94\x8c\x16root_noresmnirdtoolkit\x94\x8c./mnt/keyclim-ns9252k-volume-for-ns9034k/CMIP6/\x94\x8c\x06lustre\x94\x89\x8c\x07toolkit\x94\x88\x8c\x07sources\x94]\x94(\x8c\x0bnirdtoolkit\x94\x8c\x11noresmnirdtoolkit\x94e\x8c\x0fseperate_Noresm\x94\x88\x8c\x0ccmip_version\x94\x8c\x05CMIP6\x94\x8c\nactivities\x94]\x94(\x8c\nAerChemMIP\x94\x8c\x05RFMIP\x94e\x8c\rregrid_params\x94}\x94\x8c\x04dxdy\x94]\x94(G?\xfc\x00\x00\x00\x00\x00\x00G@\x00\x00\x00\x00\x00\x00\x00es\x8c\routput_format\x94\x8c\x07default\x94\x8c\x07out_dir\x94N\x8c\x15no_intermediate_files\x94\x89\x8c\ntime_slice\x94}\x94(\x8c\x05start\x94K\x02\x8c\x03end\x94Nu\x8c\x0fvariant_default\x94\x8c\x08r1i1p1f1\x94\x8c\x16model_specific_variant\x94}\x94(\x8c\x0epiClim-control\x94}\x94(\x8c\x0bUKESM1-0-LL\x94\x8c\x08r1i1p1f4\x94\x8c\x0bGISS-E2-1-G\x94\x8c\x08r1i1p3f1\x94\x8c\x0bCNRM-ESM2-1\x94\x8c\x08r1i1p1f2\x94\x8c\x06MIROC6\x94\x8c\tr11i1p1f1\x94\x8c\nNorESM2-LM\x94\x8c\x08r1i1p2f1\x94\x8c\x11NorESM2.0.6dev-LM\x94\x8c\x08r1i1p3f1\x94u\x8c\rpiClim-2xdust\x94}\x94(\x8c\x0bUKESM1-0-LL\x94\x8c\x08r1i1p1f4\x94\x8c\x0bGISS-E2-1-G\x94\x8c\x08r1i1p3f1\x94\x8c\x0bCNRM-ESM2-1\x94\x8c\x08r1i1p1f2\x94\x8c\nNorESM2-LM\x94\x8c\x08r1i1p2f1\x94\x8c\x11NorESM2.0.6dev-LM\x94\x8c\x08r1i1p3f1\x94uu\x8c\x0bexperiments\x94}\x94(\x8c\x07control\x94]\x94\x8c\x0epiClim-control\x94a\x8c\x0bexperiments\x94]\x94(\x8c\rpiClim-2xdust\x94\x8c\x0cabrupt-4xCO2\x94\x8c\tpi
\x94J~\xff\xff\xff\x8c\x06lonmax\x94J\xb0\xff\xff\xffu\x8c\tAustralia\x94}\x94(\x8c\x06latmin\x94J\xd8\xff\xff\xff\x8c\x06latmax\x94J\xf6\xff\xff\xff\x8c\x06lonmin\x94Kn\x8c\x06lonmax\x94K\xa0u\x8c\rSouth America\x94}\x94(\x8c\x06latmin\x94J\xc4\xff\xff\xff\x8c\x06latmax\x94K\x00\x8c\x06lonmin\x94J\xb0\xff\xff\xff\x8c\x06lonmax\x94J\xec\xff\xff\xffuu\x8c\x15dust_interest_regions\x94}\x94(\x8c\x0eNorth Atlantic\x94}\x94(\x8c\x06latmin\x94J\xfa\xff\xff\xff\x8c\x06latmax\x94K"\x8c\x06lonmin\x94J\xbe\xff\xff\xff\x8c\x06lonmax\x94J\xf0\xff\xff\xffu\x8c\x0cNorth Africa\x94}\x94(\x8c\x06latmin\x94K\n\x8c\x06latmax\x94K\x1f\x8c\x06lonmin\x94J\xf2\xff\xff\xff\x8c\x06lonmax\x94K$u\x8c\x1cMiddle East and Central Asia\x94}\x94(\x8c\x06latmin\x94K\x13\x8c\x06latmax\x94K,\x8c\x06lonmin\x94K%\x8c\x06lonmax\x94KOu\x8c\x0bArabian Sea\x94}\x94(\x8c\x06latmin\x94J\xfa\xff\xff\xff\x8c\x06latmax\x94K\x13\x8c\x06lonmin\x94K*\x8c\x06lonmax\x94KRu\x8c\tEast Asia\x94}\x94(\x8c\x06latmin\x94K\x17\x8c\x06latmax\x94K=\x8c\x06lonmin\x94KO\x8c\x06lonmax\x94Kuu\x8c\rNorth Pacific\x94}\x94(\x8c\x06latmin\x94K\x0f\x8c\x06latmax\x94K0\x8c\x06lonmin\x94Ku\x8c\x06lonmax\x94K\x93uuu\x8c\x04rule\x94\x8c&plot_dust_indirect_effect_on_chemistry\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c4/home/ovewh/Climaso/workflow/notebooks/dust_analysis\x94ub.');del script;from snakemake.logging import logger;from snakemake.script import snakemake; logger.printshellcmds = False;import os; os.chdir(r'/home/ovewh/Climaso');
######## snakemake preamble end #########

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib as mpl
import workflow.scripts.utils as util

# %%
snakemake.input.keys()
# Out:
# dict_keys(['exp_vars', 'ctrl_vars', 'derived_exp_vars', 'derived_ctrl_vars'])

# %%
xr.open_dataset(snakemake.input[6])
# Out:
# <xarray.Dataset> Size: 5MB
# Dimensions:  (time: 45, lat: 144, lon: 192)
# Coordinates:
#   * lat      (lat) float64 1kB -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#   * lon      (lon) float64 2kB 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#   * time     (time) object 360B 1850-12-30 00:00:00 ... 1894-12-30 00:00:00
# Data variables:
#     concso4  (time, lat, lon) float32 5MB ...
# Attributes: (12/61)
#     Conventions:                      CF-1.7 CMIP-6.2
#     activity_id:                      AerChemMIP
#     branch_method:                    standard
#     branch_time_in_child:             0.0
#     branch_time_in_parent:            110160.0
#     creation_date:                    2020-03-10T12:01:59Z
#     ...                               ...
#     intake_esm_attrs:activity_id:     AerChemMIP
#     intake_esm_attrs:institution_id:  MOHC
#     intake_esm_attrs:version:         20200310
#     intake_esm_attrs:path:            /nird/datalake/NS9560K/ESGF/CMIP6/AerCh...
#     intake_esm_attrs:_data_format_:   netcdf
#     intake_esm_dataset_key:           AerChemMIP.MOHC

# %%
def load_data(p):
    ds = util.load_CMIP_data(p)
    m = ds.parent_source_id
    return ds, m

# %%
exp_path = snakemake.input.derived_exp_vars + snakemake.input.exp_vars

# %%
exp_data
# Out:
# {'UKESM1-0-LL': <xarray.Dataset> Size: 15MB
#  Dimensions:  (time: 45, lat: 144, lon: 192)
#  Coordinates:
#    * lat      (lat) float64 1kB -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon      (lon) float64 2kB 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#    * time     (time) object 360B 1850-12-30 00:00:00 ... 1894-12-30 00:00:00
#  Data variables:
#      concso4  (time, lat, lon) float32 5MB ...
#      cdncvi   (time, lat, lon) float64 10MB ...
#  Attributes: (12/61)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      AerChemMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            110160.0
#      creation_date:                    2020-03-10T12:01:59Z
#      ...                               ...
#      intake_esm_attrs:activity_id:     AerChemMIP
#      intake_esm_attrs:institution_id:  MOHC
#      intake_esm_attrs:version:         20200310
#      intake_esm_attrs:path:            /nird/datalake/NS9560K/ESGF/CMIP6/AerCh...
#      intake_esm_attrs:_data_format_:   netcdf
#      intake_esm_dataset_key:           AerChemMIP.MOHC,
#  'MPI-ESM-1-2-HAM': <xarray.Dataset> Size: 9MB
#  Dimensions:  (lat: 96, lon: 192, time: 30)
#  Coordinates:
#    * lat      (lat) float64 768B -88.57 -86.72 -84.86 -83.0 ... 84.86 86.72 88.57
#    * lon      (lon) float64 2kB 0.0 1.875 3.75 5.625 ... 352.5 354.4 356.2 358.1
#    * time     (time) datetime64[ns] 240B 1850-12-31 1851-12-31 ... 1879-12-31
#  Data variables:
#      concso4  (time, lat, lon) float64 4MB ...
#      cdncvi   (time, lat, lon) float64 4MB ...
#  Attributes: (12/56)
#      Conventions:                      CF-1.7 CMIP-6.2
#      activity_id:                      AerChemMIP
#      branch_method:                    standard
#      branch_time_in_child:             0.0
#      branch_time_in_parent:            36524.0
#      contact:                          david.neubauer@env.ethz.ch
#      ...                               ...
#      intake_esm_attrs:grid_label:      gn
#      intake_esm_attrs:activity_id:     AerChemMIP
#      intake_esm_attrs:institution_id:  HAMMOZ-Consortium
#      intake_esm_attrs:version:         20200120
#      intake_esm_attrs:_data_format_:   netcdf
#      intake_esm_dataset_key:           AerChemMIP.HAMMOZ-Consortium,
#  'EC-Earth3-AerChem': <xarray.Dataset> Size: 104MB
#  Dimensions:  (lat: 346, lon: 624, time: 30)
#  Coordinates:
#    * lat      (lat) float64 3kB -89.46 -89.0 -88.77 -88.07 ... 88.77 89.0 89.46
#    * lon      (lon) float64 5kB 0.0 0.7031 1.406 1.5 ... 357.9 358.5 358.6 359.3
#    * time     (time) datetime64[ns] 240B 1850-12-31 1851-12-31 ... 1879-12-31
#  Data variables:
#      concso4  (time, lat, lon) float64 52MB nan nan nan nan ... nan nan nan nan
#      cdncvi   (time, lat, lon) float64 52MB 3.738e+10 3.739e+10 ... 2.782e+11
#  Attributes: (12/56)
#      Conventions:                        CF-1.7 CMIP-6.2
#      activity_id:                        AerChemMIP
#      branch_method:                      standard
#      branch_time_in_child:               0.0
#      branch_time_in_parent:              0.0
#      contact:                            cmip6-data@ec-earth.org
#      ...                                 ...
#      intake_esm_attrs:grid_label:        gn
#      intake_esm_attrs:activity_id:       AerChemMIP
#      intake_esm_attrs:institution_id:    EC-Earth-Consortium
#      intake_esm_attrs:version:           20210615
#      intake_esm_attrs:_data_format_:     netcdf
#      intake_esm_dataset_key:             AerChemMIP.EC-Earth-Consortium}

# %%
exp_data = {}
for p in exp_path:
    ds = xr.open_dataset(p)
    m = ds.parent_source_id
    if exp_data.get(m, None) is None:
        exp_data[m] = ds
    else:
        exp_data[m] = exp_data[m].merge(ds)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/coding/times.py:326, in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     325 try:
# --> 326     dates = _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     327 except (KeyError, OutOfBoundsDatetime, OutOfBoundsTimedelta, OverflowError):
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/coding/times.py:252, in _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     251 if not _is_standard_calendar(calendar):
# --> 252     raise OutOfBoundsDatetime(
#     253         f"Cannot decode times from a non-standard calendar, {calendar!r}, using "
#     254         "pandas."
#     255     )
#     257 time_units, ref_date_str = _unpack_netcdf_time_units(units)
#
# OutOfBoundsDatetime: Cannot decode times from a non-standard calendar, '360_day', using pandas.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/coding/times.py:218, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime)
#     217 try:
# --> 218     result = decode_cf_datetime(example_value, units, calendar, use_cftime)
#     219 except Exception:
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/coding/times.py:333, in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     328 dates = _decode_datetime_with_cftime(
#     329     flat_num_dates.astype(float), units, calendar
#     330 )
#     332 if (
# --> 333     dates[np.nanargmin(num_dates)].year < 1678
#     334     or dates[np.nanargmax(num_dates)].year >= 2262
#     335 ):
#     336     if _is_standard_calendar(calendar):
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:569, in nanargmin(a, axis, out, keepdims)
#     568     if np.any(mask):
# --> 569         raise ValueError("All-NaN slice encountered")
#     570 res = np.argmin(a, axis=axis, out=out, keepdims=keepdims)
#
# ValueError: All-NaN slice encountered
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/conventions.py:450, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     449 try:
# --> 450     new_vars[k] = decode_cf_variable(
#     451         k,
#     452         v,
#     453         concat_characters=_item_or_default(concat_characters, k, True),
#     454         mask_and_scale=_item_or_default(mask_and_scale, k, True),
#     455         decode_times=_item_or_default(decode_times, k, True),
#     456         stack_char_dim=stack_char_dim,
#     457         use_cftime=_item_or_default(use_cftime, k, None),
#     458         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     459     )
#     460 except Exception as e:
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/conventions.py:291, in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     290 if decode_times:
# --> 291     var = times.CFDatetimeCoder(use_cftime=use_cftime).decode(var, name=name)
#     293 if decode_endianness and not var.dtype.isnative:
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/coding/times.py:992, in CFDatetimeCoder.decode(self, variable, name)
#     991 calendar = pop_to(attrs, encoding, "calendar")
# --> 992 dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
#     993 transform = partial(
#     994     decode_cf_datetime,
#     995     units=units,
#     996     calendar=calendar,
#     997     use_cftime=self.use_cftime,
#     998 )
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/coding/times.py:228, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime)
#     223     msg = (
#     224         f"unable to decode time units {units!r} with {calendar_msg!r}. Try "
#     225         "opening your dataset with decode_times=False or installing cftime "
#     226         "if it is not installed."
#     227     )
# --> 228     raise ValueError(msg)
#     229 else:
#
# ValueError: unable to decode time units 'days since 1850-01-01' with "calendar '360_day'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 exp_data = {}
#       2 for p in exp_path:
# ----> 3     ds = xr.open_dataset(p)
#       4     m = ds.parent_source_id
#       5     if exp_data.get(m, None) is None:
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/backends/api.py:588, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     576 decoders = _resolve_decoders_kwargs(
#     577     decode_cf,
#     578     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     584     decode_coords=decode_coords,
#     585 )
#     587 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 588 backend_ds = backend.open_dataset(
#     589     filename_or_obj,
#     590     drop_variables=drop_variables,
#     591     **decoders,
#     592     **kwargs,
#     593 )
#     594 ds = _dataset_from_backend_dataset(
#     595     backend_ds,
#     596     filename_or_obj,
#    (...)
#     606     **kwargs,
#     607 )
#     608 return ds
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/backends/netCDF4_.py:659, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     657 store_entrypoint = StoreBackendEntrypoint()
#     658 with close_on_error(store):
# --> 659     ds = store_entrypoint.open_dataset(
#     660         store,
#     661         mask_and_scale=mask_and_scale,
#     662         decode_times=decode_times,
#     663         concat_characters=concat_characters,
#     664         decode_coords=decode_coords,
#     665         drop_variables=drop_variables,
#     666         use_cftime=use_cftime,
#     667         decode_timedelta=decode_timedelta,
#     668     )
#     669 return ds
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/backends/store.py:46, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      43 vars, attrs = filename_or_obj.load()
#      44 encoding = filename_or_obj.get_encoding()
# ---> 46 vars, attrs, coord_names = conventions.decode_cf_variables(
#      47     vars,
#      48     attrs,
#      49     mask_and_scale=mask_and_scale,
#      50     decode_times=decode_times,
#      51     concat_characters=concat_characters,
#      52     decode_coords=decode_coords,
#      53     drop_variables=drop_variables,
#      54     use_cftime=use_cftime,
#      55     decode_timedelta=decode_timedelta,
#      56 )
#      58 ds = Dataset(vars, attrs=attrs)
#      59 ds = ds.set_coords(coord_names.intersection(vars))
#
# File /opt/conda/envs/dustysnake/lib/python3.12/site-packages/xarray/conventions.py:461, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     450     new_vars[k] = decode_cf_variable(
#     451         k,
#     452         v,
#    (...)
#     458         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     459     )
#     460 except Exception as e:
# --> 461     raise type(e)(f"Failed to decode variable {k!r}: {e}") from e
#     462 if decode_coords in [True, "coordinates", "all"]:
#     463     var_attrs = new_vars[k].attrs
#
# ValueError: Failed to decode variable 'time_bnds': unable to decode time units 'days since 1850-01-01' with "calendar '360_day'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.
